# %%
from bs4 import BeautifulSoup
import requests
import re
import pandas as pd

# %%
dataframe = pd.read_csv('./dataset 3/matches_w_player_stats.csv',header=None,dtype=str)
match_ids = dataframe[0].tolist()
for id in match_ids:
    url = 'https://www.nba.com/game/'+id
    page = requests.get(url)
    soup = BeautifulSoup(page.content, 'html.parser')
    print(soup.prettify())
    #print(soup)
    break
# Out:
# <!DOCTYPE html>
# <html data-build="16175" data-version="4.44.0" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <link href="/site-manifest.json" rel="manifest"/>
#   <meta content="width=device-width,initial-scale=1,minimum-scale=1,maximum-scale=1,user-scalable=no" name="viewport"/>
#   <script src="/newrelic/newrelic-prod.js">
#   </script>
#   <script id="theme-loader" src="/theme-loader.js">
#   </script>
#   <title>
#    Portland Trail Blazers vs Los Angeles Clippers Jan 1, 2012 Game Summary | NBA.com
#   </title>
#   <meta content="Portland Trail Blazers vs Los Angeles Clippers Jan 1, 2012 game result including recap, highlights and game information" name="description"/>
#   <link href="/favicon.ico" rel="icon"/>
#   <link href="/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
#   <link href="/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
#   <link href="/apple-touch-icon.png" rel="apple-touch-icon"/>
# ...
